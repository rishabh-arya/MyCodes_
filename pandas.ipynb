# %% [markdown]
# Pandas was created by Wes McKinney in 2008, and is an open source project under a very permissive  license.We are going to look how Python can be used to manipulate, clean, and query data by looking at the Pandas data tool kit.
#
# <img src = "https://img2020.cnblogs.com/blog/90107/202010/90107-20201023153258988-844526364.png" alt="Dataframe">

# %%
# Importing libraries
import pandas as pd

# %%
# Reading the csv data file
df = pd.read_csv('./Movies.csv')

# %%
df.head()
# Out:
#                                           Title  Year   Genre  Duration  \
# 0                                   What Is It?  2005   Drama        72
# 1                                       Glitter  2001   Drama       104
# 2                         The Attic Expeditions  2001  Comedy       100
# 3                               Men in Black II  2002  Action        88
# 4  Star Wars: Episode II - Attack of the Clones  2002  Action       142
#
#              Director  Rating  Popularity
# 0      Crispin Glover     5.6       21.83
# 1  Vondie Curtis-Hall     2.2       81.69
# 2       Jeremy Kasten     5.0       42.08
# 3    Barry Sonnenfeld     6.2       98.60
# 4        George Lucas     6.5       99.58

# %%
df.tail()
# Out:
#                         Title  Year      Genre  Duration  \
# 5270                Bloodline  2018      Crime        97
# 5271      The Princess Switch  2018     Comedy       101
# 5272  You Might Be the Killer  2018     Comedy        92
# 5273           The Final Wish  2018     Horror        95
# 5274             Shrek Retold  2018  Animation        90
#
#                   Director  Rating  Popularity
# 5270        Henry Jacobson     6.0       64.69
# 5271             Mike Rohl     6.0       80.21
# 5272         Brett Simmons     5.9       61.14
# 5273  Timothy Woodward Jr.     4.2       54.68
# 5274         Grant Duffrin     7.5       26.07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5275 entries, 0 to 5274
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       5275 non-null   object
#  1   Year        5275 non-null   int64
#  2   Genre       5275 non-null   object
#  3   Duration    5275 non-null   int64
#  4   Director    5275 non-null   object
#  5   Rating      5275 non-null   float64
#  6   Popularity  5275 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 288.6+ KB

# %%
# Univariate Statistics
df.describe().T
# Out:
#              count         mean        std      min      25%      50%  \
# Year        5275.0  2010.899526   4.842039  2001.00  2007.00  2012.00
# Duration    5275.0    95.235261  12.771222    46.00    87.00    93.00
# Rating      5275.0     5.379981   1.248103     1.10     4.60     5.50
# Popularity  5275.0    50.009486  28.870229     0.05    25.03    50.02
#
#                  75%     max
# Year        2015.000  2018.0
# Duration     101.000   219.0
# Rating         6.300     9.7
# Popularity    75.005   100.0

# %%
df.columns
# Out:
# Index(['Title', 'Year', 'Genre', 'Duration', 'Director', 'Rating',
#        'Popularity'],
#       dtype='object')

# %%
# Number of unique values featurewise
df.nunique()
# Out:
# Title         5219
# Year            18
# Genre           19
# Duration       107
# Director      3772
# Rating          80
# Popularity    3684
# dtype: int64

# %%
# Visualizing data through pandas
df['Rating'].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
df['Duration'].plot(kind="kde",figsize=(12,8))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Boolean Masking
df[df['Rating'] > 8.5]
# Out:
#                                                   Title  Year     Genre  \
# 867                                          Graves End  2005  Thriller
# 2532                                      Hopeful Notes  2010     Drama
# 2871                                  All You Can Dream  2012    Comedy
# 3398                                             Wheels  2014     Drama
# 5003                                  The Transcendents  2018     Music
# 5024                                     Delaware Shore  2018     Drama
# 5083  Mr. Plinkett's Indiana Jones and the Kingdom o...  2011    Comedy
#
#       Duration                       Director  Rating  Popularity
# 867         90                  James Marlowe     8.8       68.13
# 2532        94                 Valerio Zanoli     9.7       12.03
# 2871        79                 Valerio Zanoli     8.8       23.45
# 3398       115  Tim Gagliardo, Donavon Warren     8.8       79.92
# ...

# %%
df[(df['Genre'] == "Horror") & (df['Year'] == 2018)]
# Out:
#                                      Title  Year   Genre  Duration  \
# 3215                             Hell Fest  2018  Horror        89
# 3285                              Delirium  2018  Horror        96
# 3937                             Kill Game  2018  Horror       102
# 3996                              Delirium  2018  Horror        96
# 4193                 Malevolence 3: Killer  2018  Horror        89
# ...                                    ...   ...     ...       ...
# 5262            Amityville: Mt. Misery Rd.  2018  Horror        75
# 5265                      The Fear Footage  2018  Horror        71
# 5266  Hell House LLC II: The Abaddon Hotel  2018  Horror        83
# 5269                       The Dead Center  2018  Horror        92
# 5273                        The Final Wish  2018  Horror        95
#
#                                        Director  Rating  Popularity
# 3215                            Gregory Plotkin     5.5       76.36
# ...

# %%
df[df['Year'] == 2005] = np.nan

# %%
df
# Out:
#                                              Title    Year      Genre  \
# 0                                              NaN     NaN        NaN
# 1                                          Glitter  2001.0      Drama
# 2                            The Attic Expeditions  2001.0     Comedy
# 3                                  Men in Black II  2002.0     Action
# 4     Star Wars: Episode II - Attack of the Clones  2002.0     Action
# ...                                            ...     ...        ...
# 5270                                     Bloodline  2018.0      Crime
# 5271                           The Princess Switch  2018.0     Comedy
# 5272                       You Might Be the Killer  2018.0     Comedy
# 5273                                The Final Wish  2018.0     Horror
# 5274                                  Shrek Retold  2018.0  Animation
#
#       Duration              Director  Rating  Popularity
# 0          NaN                   NaN     NaN         NaN
# ...

# %%
# Checking the NULL values
df.isna().sum()
# Out:
# Title         210
# Year          210
# Genre         210
# Duration      210
# Director      210
# Rating        210
# Popularity    210
# dtype: int64

# %%
# how = any or all 
# axis = 0 : horizontal and 1 : vertical 
df.dropna(axis=0,how="any",inplace=True)

# %%
df.isna().sum()
# Out:
# Title         0
# Year          0
# Genre         0
# Duration      0
# Director      0
# Rating        0
# Popularity    0
# dtype: int64

# %%
# Creating a Dataframe
import numpy as np
data1 = np.arange(0,100,2)
data2 = np.sin(data1)
data3 = np.random.rand(50)

# %%
data = pd.DataFrame(np.c_[data1,data2,data3],columns=['Even_values','Sin_values','Random_values'])
data.head()
# Out:
#    Even_values  Sin_values  Random_values
# 0          0.0    0.000000       0.650472
# 1          2.0    0.909297       0.880969
# 2          4.0   -0.756802       0.999985
# 3          6.0   -0.279415       0.540484
# 4          8.0    0.989358       0.368470

# %%
data.to_csv('./data.csv',header=True,index=False)
